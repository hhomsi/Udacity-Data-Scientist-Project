# %% [markdown]
# #### Developer Type
#
# What are the most common types of developers and their distribution in the industry?

# %%
import pandas as pd
import numpy as np
# import JobSatisfaction as t
import HowToBreakIntoTheField as t
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('./survey_results_public.csv')
schema = pd.read_csv('./survey_results_schema.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
def clean_and_plot(df, title='Developer Type', plot=True):
    
    dev_type = df['DeveloperType'].value_counts().reset_index()
    dev_type.rename(columns={'index': 'Developer Type', 'DeveloperType': 'count'}, inplace=True)
    dev_type_df = t.total_count(dev_type, 'Developer Type', 'count', possible_vals)

    dev_type_df.set_index('Developer Type', inplace=True)
    if plot:
        (dev_type_df/dev_type_df.sum()).plot(kind='bar', legend=None);
        plt.title(title);
        plt.show()
    props_dev_type = dev_type_df/dev_type_df.sum()
        
    return props_dev_type
    
props_df = clean_and_plot(df)
