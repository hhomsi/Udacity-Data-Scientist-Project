# %% [markdown]
# #### Job Satisfaction
#
# How do job satisfaction levels vary by Country, Employment Status or Company Size?

# %%
import pandas as pd
import numpy as np
# import JobSatisfaction as t
import HowToBreakIntoTheField as t
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('./survey_results_public.csv')
schema = pd.read_csv('./survey_results_schema.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %% [markdown]
# #### Used to Answer Question 1

# %%
# Group by country, then calculate mean job satisfaction
country_devtype_satisfaction = df.groupby(['Country']).mean()['JobSatisfaction'].sort_values().dropna()

country_devtype_satisfaction
# Out:
# Country
# North Korea                        0.000000
# Fiji                               0.000000
# Somalia                            2.000000
# Brunei Darussalam                  3.000000
# Bhutan                             3.000000
# Lesotho                            3.000000
# Gabon                              4.000000
# Oman                               4.000000
# Uzbekistan                         4.200000
# Trinidad and Tobago                4.600000
# Uganda                             4.625000
# Syria                              4.666667
# Kyrgyzstan                         5.000000
# Ivory Coast (Cote D'Ivoire)        5.000000
# Togo                               5.000000
# Zaire                              5.000000
# Mozambique                         5.000000
# Mauritius                          5.000000
# Myanmar                            5.181818
# Ghana                              5.428571
# Liechtenstein                      5.500000
# ...

# %%
# Group by EmploymentStatus, then calculate mean job satisfaction

df.groupby(['EmploymentStatus']).mean()['JobSatisfaction'].sort_values().dropna()
# Out:
# EmploymentStatus
# Employed part-time                                      6.846154
# Employed full-time                                      6.980608
# Independent contractor, freelancer, or self-employed    7.231985
# Name: JobSatisfaction, dtype: float64

# %%
# Group by CompanySize, then calculate mean job satisfaction

df.groupby(['CompanySize']).mean()['JobSatisfaction'].sort_values().sort_values().dropna()
# Out:
# CompanySize
# 10,000 or more employees    6.793617
# 5,000 to 9,999 employees    6.832155
# 1,000 to 4,999 employees    6.908506
# 20 to 99 employees          6.997039
# Fewer than 10 employees     7.025719
# 100 to 499 employees        7.029324
# 500 to 999 employees        7.029967
# 10 to 19 employees          7.035739
# I don't know                7.054622
# I prefer not to answer      7.284946
# Name: JobSatisfaction, dtype: float64
